# %%
import numpy as np
salary=np.array([20000,30000,25000,35000,60000])
experience=np.array([1,2,2,3,5])

np.corrcoef(salary,experience)
# Out:
# array([[1.        , 0.98447154],
#        [0.98447154, 1.        ]])
