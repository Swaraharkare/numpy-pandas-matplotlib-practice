# %%
import numpy as np
a=np.array([19,34,90,54,3,87,11,23,59,75,64,88,94,67])
print(a)
# Out:
# [19 34 90 54  3 87 11 23 59 75 64 88 94 67]

# %%
#np.histogram() function which represents the frequency of data distribution in the graphical form
np.histogram(a,bins=[0,25,50,75,100])
# Out:
# (array([4, 1, 4, 5]), array([  0,  25,  50,  75, 100]))
