# %%
import numpy as np
a=np.arange(10,20)
b=np.arange(10,20,2)
# Out:
# array([10, 12, 14, 16, 18])

# %%
np.isin(a,b)
# Out:
# array([ True, False,  True, False,  True, False,  True, False,  True,
#        False])
