# %%
import numpy as np
a=np.array([10,23,45,98,55,34,90,67,87,23,76,12,56])
#where() give index of element where given condition satisfied
np.where(a>50)
# Out:
# (array([ 3,  4,  6,  7,  8, 10, 12]),)

# %%
#replace values > with 0----np.where(condition,true,false)
np.where(a>50,0,a)
# Out:
# array([10, 23, 45,  0,  0, 34,  0,  0,  0, 23,  0, 12,  0])
