# %%
#np.nan is attribute of numpy 
import numpy as np

a=np.array([1,2,3,4,np.nan,6,7,8,9,10])
a
# Out:
# array([ 1.,  2.,  3.,  4., nan,  6.,  7.,  8.,  9., 10.])

# %%
a[~(np.isnan(a))]
# Out:
# array([ 1.,  2.,  3.,  4.,  6.,  7.,  8.,  9., 10.])
